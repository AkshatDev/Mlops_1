# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/MyDrive/simple')

# %%
#! pip install -r requirements.txt
#! pip install dvc'[gdrive]'
# Out:
# ERROR: Invalid requirement: "dvc'[gdrive]'" (from line 2 of requirements.txt)

# %%
# !git init
# !dvc init
# !dvc add data_given/winequality.csv
# Out:
# Reinitialized existing Git repository in /content/gdrive/My Drive/simple/.git/
# Initialized DVC repository.
#
# You can now commit the changes to git.
#
# +---------------------------------------------------------------------+
# |                                                                     |
# |        DVC has enabled anonymous aggregate usage analytics.         |
# |     Read the analytics documentation (and how to opt-out) here:     |
# |             <https://dvc.org/doc/user-guide/analytics>              |
# |                                                                     |
# +---------------------------------------------------------------------+
#
# What's next?
# ------------
# - Check out the documentation: <https://dvc.org/doc>
# - Get help and share ideas: <https://dvc.org/chat>
# - Star us on GitHub: <https://github.com/iterative/dvc>
# Add:   0% 0/1 [00:00<?, ?file/s{'info': ''}]
# .g4KGFFBdfeH8ULdHXgE5Y5.tmp:   0% 0.00/92.0k [00:00<?, ?it/s]
# ...

# %%
git add .
