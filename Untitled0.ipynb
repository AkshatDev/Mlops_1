# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/MyDrive/simple')

# %%
#! pip install -r requirements.txt
#! pip install 'dvc[gdrive]'

# %%
# !git init
# !dvc init
#!dvc add data_given/winequality.csv
# Out:
# Reinitialized existing Git repository in /content/gdrive/My Drive/simple/.git/
# ERROR: failed to initiate DVC - '.dvc' exists. Use `-f` to force.

# %%
# !git add .

# %%
# !git config --global user.email "akshat.thakur8@gmail.com"
# !git config --global user.name "AkshatDev"

# %%
#!git branch -M main

#!git remote add origin https://AkshatDev:akshat4374@github.com/AkshatDev/Mlops_1.git (dont run this again and again)
# !git push -u origin main
# Out:
# Counting objects: 23, done.
# Delta compression using up to 4 threads.
# Compressing objects: 100% (18/18), done.
# Writing objects: 100% (23/23), 5.26 KiB | 316.00 KiB/s, done.
# Total 23 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), done.
# To https://github.com/AkshatDev/Mlops_1.git
#  * [new branch]      main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !dvc repro
# Out:
# Verifying data sources in stage: 'data_given/winequality.csv.dvc'
#
# Running stage 'load_data':
# > python src/load_data.py --config=params.yaml
# Generating lock file 'dvc.lock'
# Updating lock file 'dvc.lock'
#
# Running stage 'split_data':
# > python src/split_data.py --config=params.yaml
# Updating lock file 'dvc.lock'
#
# To track the changes with git, run:
#
# 	git add data_given/winequality.csv.dvc data/processed/.gitignore data/raw/.gitignore dvc.lock
# Use `dvc push` to send your updates to remote storage.

# %%
# !git add .
! git commit -m "dvc repro till stage 2"
# Out:
# [main 0486c83] dvc repro till stage 2
#  10 files changed, 162 insertions(+), 1 deletion(-)
#  create mode 100644 data/processed/.gitignore
#  create mode 100644 data/raw/.gitignore
#  create mode 100644 dvc.lock
#  create mode 100644 src/__pycache__/get_data.cpython-37.pyc
#  create mode 100644 src/get_data.py
#  create mode 100644 src/load_data.py
#  create mode 100644 src/split_data.py

# %%
! git push -u origin main
# Out:
# Counting objects: 4, done.
# Delta compression using up to 4 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 472 bytes | 157.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/AkshatDev/Mlops_1.git
#    0486c83..da994a6  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
#!dvc remote add -d <remote name> <remote url>
#!dvc remote add -d storage gdrive://164ETXniIPVMbAO3q5nisj8-5CUOi0URt
# !dvc push
# Out:
# Everything is up to date.

# %%
# !dvc repro
# Out:
# 'data_given/winequality.csv.dvc' didn't change, skipping
# Stage 'load_data' didn't change, skipping
# Stage 'split_data' didn't change, skipping
# Running stage 'train_and_evaluate':
# > python src/train_and_evaluate.py --config=params.yaml
# Elasticnet model (alpha=0.900000, l1_ratio=0.400000):
#   RMSE: 0.8031192316982254
#   MAE: 0.6551462834843995
#   R2: 0.013014969842177981
# Updating lock file 'dvc.lock'
#
# To track the changes with git, run:
#
# 	git add dvc.lock
# Use `dvc push` to send your updates to remote storage.

# %%
! git add .
! git commit -m "updated on 28 "
# !git push -u origin
# Out:
# [main 5b92fb2] updated on 28
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Untitled0.ipynb (95%)
# Counting objects: 3, done.
# Delta compression using up to 4 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.02 KiB | 262.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/AkshatDev/Mlops_1.git
#    c5a1550..5b92fb2  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !dvc metrics diff
# Out:
# If DVC froze, see `hardlink_lock` in <https://man.dvc.org/config#core>

# %%
! pytest -v
# Out:
# ============================= test session starts ==============================
# platform linux2 -- Python 2.7.17, pytest-3.6.4, py-1.8.0, pluggy-0.7.1 -- /usr/bin/python2
# cachedir: .pytest_cache
# rootdir: /content/gdrive/My Drive/simple, inifile:
# collected 1 item
#
# tests/test_config.py::test_generic PASSED                                [100%]
#
# =========================== 1 passed in 0.62 seconds ===========================

# %%
! tox -r

# %%
import pandas as pd

# %%
df=pd.read_csv('data/raw/winequality.csv')

# %%
overview=df.describe()

# %%
overview.loc[['min','max']].to_json('schema_in.json')

# %%
! flask --version
# Out:
# Python 2.7.17
# Flask 1.1.1
# Werkzeug 0.15.5

# %%
! python app.py
# Out:
#  * Serving Flask app "app" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 185-086-195
# python -m webbrowser "http://0.0.0.0:5000/"
